# %% [markdown]
# # Week 04 > Day 3
# > 🗣 Priyesh, Feb 12, 2020

# %% [markdown]
# ## 👨🏻‍💻 Today
#
# - review insertion sort > ⭐️ repetition of recursion basics

# %% [markdown]
# ***

# %% [markdown]
# # 🗣 Review insertion sort

# %% [markdown]
# ## ⏰ Time complexity
#
# - worst case O(n^2)
#     - sigma of 1 + 2 + 3 + ... + (n-1) = n*(n-1)/2 = (n^2) in the worst case
# - best case O(n) when for loop never runs
#     - 1 + 1 + 1 + 1 ... + n times = n that is O(n) in best case
#
# ## 👽 Space complexity
#
# - selection sort -- O(1)
# - bubble sort --
# - insertion sort -- O(1)
# - couting sort -- O(range(input))

# %% [markdown]
# *Code snippet 1 to sort a list using insertion sort*

# %%
import time

def insertionSort(L):
  n = len(L)
  L2 = []
  for i in range(n):
    val = L.pop(0)
    if L2 == []:
      L2 = [val]
    else:
      # insertIntoList(L, n, elem)
      L2 = insertIntoList(L2,len(L2),val) # here we do recursion (calling function inside function)
  return L2

t = time.time()
L = [5, 3, 4, 1, 8]
print("Original List: ", L)
L = insertionSort(L)
print("Sorted List:", L)
print("time taken: ", time.time()-t)
# Out:
# Original List:  [5, 3, 4, 1, 8]
# Sorted List: [1, 3, 4, 5, 8]
# time taken:  0.008320093154907227

# %% [markdown]
# ***

# %% [markdown]
# # 🗣 Recursion basics
#
# > **"This is a very very very very important topic" -- Priyesh**
#
# - ☠️ don't print stuff to test in recursion, it will confuse the hec out of you
# - recursion ALWAYS take more space than loops << *never forget this line*

# %% [markdown]
# ## 👨🏻‍💻 Factorial  example
#
# - general formual for any number n
#     - n! = n * (n-1)!
#     - 0! = 1
#     - 1! = 1
# - recursion tree, remember calculation is happening from top to up
#     ![image.png](attachment:image.png)

# %% [markdown]
# *Code snippet 2 -- find factorial of a number*

# %%
def fact(n):
    if n <= 1:
        return 1
    else:
        return n * fact(n-1)

print(fact(3))
# Out:
# 6

# %% [markdown]
# ## 👨🏻‍💻 Fibonacci example
#
# - recursion tree
#     ![image.png](attachment:image.png)

# %% [markdown]
# *Code snippet 3 -- find fibonacci factorial*

# %%
def fibo(n):
    if n <= 1:
        return n
    return fibo(n-1)+fibo(n-2)

print(fibo(7))
# Out:
# 13

# %% [markdown]
# *Code snippet 4 -- returing change example, from week04-day2 lecture*

# %%
# PROBLEM
# count coins
# amount = ₹ 5
# ₹ 1 coin, ₹ 2 coin, ₹ 5 coin
# figure out the number of ways to return change


# LOGIC
# if amt < 0, return 0
# if amt =1, return 1
# if amt > 0, return mways(amt-1)+nways(amt-2)+nways(amt-5)

def numWays(amt):
    pass # tommorow we'll code this portion

amt = int(input())
if amt <= 0:
    print("no owned money")
else:
    # call numWays
    
# ... continue tommorow
# Out:
#   File "<ipython-input-14-cd296d6883e1>", line 22
#     # ... continue tommorow
#                            ^
# SyntaxError: unexpected EOF while parsing

# %% [markdown]
# ***

# %% [markdown]
# *end of week 04 day 3*
